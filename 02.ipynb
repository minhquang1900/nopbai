# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_dir = 'D:/hoctap/ki1nam4/thigiacmaytinh/anh'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (225, 225)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x225>
# (196, 257)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=196x257>
# (168, 300)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>
